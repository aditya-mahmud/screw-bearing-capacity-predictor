# %%
import pandas as pd
import numpy as np
from catboost import CatBoostRegressor, Pool
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import optuna
import joblib

# Load the dataset
df = pd.read_excel('screw_database_ML.xlsx')

# Drop unnecessary columns
df = df.drop(columns=[df.columns[0]], errors='ignore')

# Handling missing values
df = df.dropna()

# Splitting features and target variable
X = df.drop(columns=['Pn'])
y = df['Pn']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=19)

# Standardization for both X and y
scaler_X = StandardScaler()
scaler_y = StandardScaler()

# Fit and transform the training data for X and y
X_train = scaler_X.fit_transform(X_train)
X_test = scaler_X.transform(X_test)

y_train = scaler_y.fit_transform(y_train.values.reshape(-1, 1)).ravel()  # Reshape y_train for scaling
y_test = scaler_y.transform(y_test.values.reshape(-1, 1)).ravel()  # Reshape y_test for scaling

# Define the objective function for Optuna
def objective(trial):
    params = {
        'iterations': trial.suggest_int('iterations', 500, 2000),
        'depth': trial.suggest_int('depth', 4, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1e-5, 10),
        'border_count': trial.suggest_int('border_count', 32, 255),
        'loss_function': 'RMSE',
        'verbose': 0
    }
    
    model = CatBoostRegressor(**params)
    model.fit(X_train, y_train, eval_set=(X_test, y_test), early_stopping_rounds=100, verbose=0)
    
    y_pred = model.predict(X_test)
    return mean_squared_error(y_test, y_pred)

# Run Optuna optimization
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)

# Train final model with best parameters
best_params = study.best_params
final_model = CatBoostRegressor(**best_params)
final_model.fit(X_train, y_train, eval_set=(X_test, y_test), early_stopping_rounds=100, verbose=0)

# Cross-validation with 10 folds
kf = KFold(n_splits=10, shuffle=True, random_state=19)

# Initialize lists to store results
cv_rmse = []
cv_r2 = []
cv_mae = []

for train_index, val_index in kf.split(X_train):
    X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
    y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]
    
    model = CatBoostRegressor(**best_params)
    model.fit(X_train_fold, y_train_fold, eval_set=(X_val_fold, y_val_fold), early_stopping_rounds=100, verbose=0)
    
    y_pred_fold = model.predict(X_val_fold)
    
    # Evaluate fold metrics
    rmse = np.sqrt(mean_squared_error(y_val_fold, y_pred_fold))
    r2 = r2_score(y_val_fold, y_pred_fold)
    mae = mean_absolute_error(y_val_fold, y_pred_fold)
    
    cv_rmse.append(rmse)
    cv_r2.append(r2)
    cv_mae.append(mae)

# Average results of cross-validation
avg_cv_rmse = np.mean(cv_rmse)
avg_cv_r2 = np.mean(cv_r2)
avg_cv_mae = np.mean(cv_mae)

# Predictions on the final test set
y_pred_train = final_model.predict(X_train)
y_pred_val = final_model.predict(X_test)

# Evaluation on training and testing sets
mae_train = mean_absolute_error(y_train, y_pred_train)
mse_train = mean_squared_error(y_train, y_pred_train)
r2_train = r2_score(y_train, y_pred_train)

mae_test = mean_absolute_error(y_test, y_pred_val)
mse_test = mean_squared_error(y_test, y_pred_val)
r2_test = r2_score(y_test, y_pred_val)

# Adjusted R2 calculation
def adjusted_r2(r2, n, k):
    return 1 - (1 - r2) * (n - 1) / (n - k - 1)

adj_r2_train = adjusted_r2(r2_train, len(y_train), X_train.shape[1])
adj_r2_test = adjusted_r2(r2_test, len(y_test), X_test.shape[1])

# Print results
print("Best Parameters:", best_params)
print("Mean Absolute Error (Train):", mae_train)
print("Mean Squared Error (Train):", mse_train)
print("R2 Score (Train):", r2_train)
print("Adjusted R2 Score (Train):", adj_r2_train)
print("Mean Absolute Error (Test):", mae_test)
print("Mean Squared Error (Test):", mse_test)
print("R2 Score (Test):", r2_test)
print("Adjusted R2 Score (Test):", adj_r2_test)

print("10-Fold Cross Validation Results:")
print(f"Avg RMSE: {avg_cv_rmse}")
print(f"Avg R2: {avg_cv_r2}")
print(f"Avg MAE: {avg_cv_mae}")
# Out:
# [I 2025-06-30 11:38:44,510] A new study created in memory with name: no-name-7db5eb85-541c-4b67-8934-89a80e99c1b9
# [I 2025-06-30 11:38:46,907] Trial 0 finished with value: 0.03244629195744682 and parameters: {'iterations': 1491, 'depth': 9, 'learning_rate': 0.01118744095636558, 'l2_leaf_reg': 5.557732860279044, 'border_count': 35}. Best is trial 0 with value: 0.03244629195744682.
# [I 2025-06-30 11:38:47,194] Trial 1 finished with value: 0.022794272327173355 and parameters: {'iterations': 932, 'depth': 7, 'learning_rate': 0.27052210336970756, 'l2_leaf_reg': 4.3181570155101845, 'border_count': 233}. Best is trial 1 with value: 0.022794272327173355.
# [I 2025-06-30 11:38:48,911] Trial 2 finished with value: 0.025612546239296857 and parameters: {'iterations': 745, 'depth': 10, 'learning_rate': 0.08839316806673586, 'l2_leaf_reg': 7.177953486676439, 'border_count': 205}. Best is trial 1 with value: 0.022794272327173355.
# [I 2025-06-30 11:38:49,092] Trial 3 finished with value: 0.02293151072207 and parameters: {'iterations': 1457, 'depth': 7, 'learning_rate': 0.2650153780249553, 'l2_leaf_reg': 0.12362485540607376, 'border_count': 194}. Best is trial 1 with value: 0.022794272327173355.
# [I 2025-06-30 11:38:49,734] Trial 4 finished with value: 0.03963170030135239 and parameters: {'iterations': 760, 'depth': 7, 'learning_rate': 0.02259610479659926, 'l2_leaf_reg': 9.677691617962367, 'border_count': 237}. Best is trial 1 with value: 0.022794272327173355.
# [I 2025-06-30 11:38:51,464] Trial 5 finished with value: 0.02423673636404136 and parameters: {'iterations': 1181, 'depth': 9, 'learning_rate': 0.06453489460062888, 'l2_leaf_reg': 7.437501072030595, 'border_count': 223}. Best is trial 1 with value: 0.022794272327173355.
# [I 2025-06-30 11:38:52,035] Trial 6 finished with value: 0.022466560299171427 and parameters: {'iterations': 1117, 'depth': 4, 'learning_rate': 0.03655824633988292, 'l2_leaf_reg': 1.4356614838226502, 'border_count': 224}. Best is trial 6 with value: 0.022466560299171427.
# [I 2025-06-30 11:38:52,456] Trial 7 finished with value: 0.025696647201940426 and parameters: {'iterations': 737, 'depth': 5, 'learning_rate': 0.13564302685191748, 'l2_leaf_reg': 3.832544444026069, 'border_count': 230}. Best is trial 6 with value: 0.022466560299171427.
# [I 2025-06-30 11:38:53,145] Trial 8 finished with value: 0.02528101705484705 and parameters: {'iterations': 1359, 'depth': 8, 'learning_rate': 0.12679397678762472, 'l2_leaf_reg': 5.119548948204471, 'border_count': 156}. Best is trial 6 with value: 0.022466560299171427.
# [I 2025-06-30 11:38:53,402] Trial 9 finished with value: 0.019892378229306427 and parameters: {'iterations': 1720, 'depth': 7, 'learning_rate': 0.27653678913797153, 'l2_leaf_reg': 5.809393806072691, 'border_count': 225}. Best is trial 9 with value: 0.019892378229306427.
# [I 2025-06-30 11:38:53,720] Trial 10 finished with value: 0.024291749416618793 and parameters: {'iterations': 1973, 'depth': 5, 'learning_rate': 0.2083599680729086, 'l2_leaf_reg': 2.5461863104473714, 'border_count': 89}. Best is trial 9 with value: 0.019892378229306427.
# [I 2025-06-30 11:38:54,030] Trial 11 finished with value: 0.019797516238502393 and parameters: {'iterations': 1806, 'depth': 4, 'learning_rate': 0.19970320725629379, 'l2_leaf_reg': 0.7427894446683498, 'border_count': 163}. Best is trial 11 with value: 0.019797516238502393.
# [I 2025-06-30 11:38:54,504] Trial 12 finished with value: 0.02177631610893147 and parameters: {'iterations': 1926, 'depth': 5, 'learning_rate': 0.21587860683125673, 'l2_leaf_reg': 6.422382209374181, 'border_count': 154}. Best is trial 11 with value: 0.019797516238502393.
# [I 2025-06-30 11:38:55,031] Trial 13 finished with value: 0.020446503819506197 and parameters: {'iterations': 1723, 'depth': 4, 'learning_rate': 0.20461107321849067, 'l2_leaf_reg': 9.080854783402856, 'border_count': 113}. Best is trial 11 with value: 0.019797516238502393.
# [I 2025-06-30 11:38:55,251] Trial 14 finished with value: 0.02235747164721206 and parameters: {'iterations': 1706, 'depth': 6, 'learning_rate': 0.2819585117497305, 'l2_leaf_reg': 2.9042880204944708, 'border_count': 163}. Best is trial 11 with value: 0.019797516238502393.
# [I 2025-06-30 11:38:55,428] Trial 15 finished with value: 0.020993354985922252 and parameters: {'iterations': 1710, 'depth': 6, 'learning_rate': 0.23576585562928803, 'l2_leaf_reg': 0.07162883757593663, 'border_count': 192}. Best is trial 11 with value: 0.019797516238502393.
# [I 2025-06-30 11:38:55,726] Trial 16 finished with value: 0.02538702307793025 and parameters: {'iterations': 1595, 'depth': 8, 'learning_rate': 0.17802640572879116, 'l2_leaf_reg': 1.779233365751705, 'border_count': 255}. Best is trial 11 with value: 0.019797516238502393.
# [I 2025-06-30 11:38:56,314] Trial 17 finished with value: 0.02167646361388348 and parameters: {'iterations': 1862, 'depth': 6, 'learning_rate': 0.1677520773543681, 'l2_leaf_reg': 6.283580046492528, 'border_count': 120}. Best is trial 11 with value: 0.019797516238502393.
# [I 2025-06-30 11:38:56,672] Trial 18 finished with value: 0.020579664125971293 and parameters: {'iterations': 1317, 'depth': 4, 'learning_rate': 0.2416743434116583, 'l2_leaf_reg': 7.986602542038134, 'border_count': 175}. Best is trial 11 with value: 0.019797516238502393.
# [I 2025-06-30 11:38:57,226] Trial 19 finished with value: 0.03860763437999269 and parameters: {'iterations': 1807, 'depth': 10, 'learning_rate': 0.29819413407292805, 'l2_leaf_reg': 3.893369631094528, 'border_count': 129}. Best is trial 11 with value: 0.019797516238502393.
# [I 2025-06-30 11:38:57,738] Trial 20 finished with value: 0.023923771381292824 and parameters: {'iterations': 535, 'depth': 8, 'learning_rate': 0.2477564162275687, 'l2_leaf_reg': 8.688177774669693, 'border_count': 75}. Best is trial 11 with value: 0.019797516238502393.
# [I 2025-06-30 11:38:58,371] Trial 21 finished with value: 0.02296440303683466 and parameters: {'iterations': 1644, 'depth': 4, 'learning_rate': 0.19231110785120373, 'l2_leaf_reg': 9.97700048300386, 'border_count': 104}. Best is trial 11 with value: 0.019797516238502393.
# [I 2025-06-30 11:38:59,072] Trial 22 finished with value: 0.02123564132269448 and parameters: {'iterations': 1513, 'depth': 5, 'learning_rate': 0.1429910358271999, 'l2_leaf_reg': 8.31863648097688, 'border_count': 133}. Best is trial 11 with value: 0.019797516238502393.
# [I 2025-06-30 11:38:59,449] Trial 23 finished with value: 0.02138040240018879 and parameters: {'iterations': 1809, 'depth': 4, 'learning_rate': 0.21156995953232077, 'l2_leaf_reg': 6.094153717823228, 'border_count': 61}. Best is trial 11 with value: 0.019797516238502393.
# [I 2025-06-30 11:39:00,171] Trial 24 finished with value: 0.018762710343842665 and parameters: {'iterations': 1992, 'depth': 6, 'learning_rate': 0.188457495394322, 'l2_leaf_reg': 9.222947633613158, 'border_count': 107}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:00,547] Trial 25 finished with value: 0.021065655560783984 and parameters: {'iterations': 2000, 'depth': 6, 'learning_rate': 0.11734219076626792, 'l2_leaf_reg': 0.9444504095980797, 'border_count': 177}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:01,033] Trial 26 finished with value: 0.022100575526282324 and parameters: {'iterations': 1846, 'depth': 6, 'learning_rate': 0.1606802149731093, 'l2_leaf_reg': 2.9245126870741425, 'border_count': 142}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:01,639] Trial 27 finished with value: 0.020356848574662783 and parameters: {'iterations': 1584, 'depth': 7, 'learning_rate': 0.18340312328339478, 'l2_leaf_reg': 7.170191848593832, 'border_count': 82}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:02,086] Trial 28 finished with value: 0.022980061640737855 and parameters: {'iterations': 1912, 'depth': 8, 'learning_rate': 0.2992961034443463, 'l2_leaf_reg': 4.933113221052082, 'border_count': 101}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:02,676] Trial 29 finished with value: 0.02926840249764484 and parameters: {'iterations': 1459, 'depth': 9, 'learning_rate': 0.22422578608891042, 'l2_leaf_reg': 5.425991395149058, 'border_count': 55}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:03,864] Trial 30 finished with value: 0.02534939214154025 and parameters: {'iterations': 1994, 'depth': 5, 'learning_rate': 0.09297207351164327, 'l2_leaf_reg': 9.232735178101263, 'border_count': 209}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:04,492] Trial 31 finished with value: 0.022881136045487173 and parameters: {'iterations': 1584, 'depth': 7, 'learning_rate': 0.18405680857454917, 'l2_leaf_reg': 7.115775358311801, 'border_count': 87}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:05,306] Trial 32 finished with value: 0.020467409762542847 and parameters: {'iterations': 1778, 'depth': 7, 'learning_rate': 0.1569444413234693, 'l2_leaf_reg': 7.875989849514947, 'border_count': 38}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:05,665] Trial 33 finished with value: 0.02275963422539948 and parameters: {'iterations': 1652, 'depth': 7, 'learning_rate': 0.19284643372698915, 'l2_leaf_reg': 6.69584355877425, 'border_count': 72}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:06,004] Trial 34 finished with value: 0.02418181963550911 and parameters: {'iterations': 1533, 'depth': 8, 'learning_rate': 0.25615369424331086, 'l2_leaf_reg': 5.766672204414265, 'border_count': 255}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:06,281] Trial 35 finished with value: 0.021964789473014383 and parameters: {'iterations': 1742, 'depth': 7, 'learning_rate': 0.27330984269318637, 'l2_leaf_reg': 4.669524300430461, 'border_count': 92}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:06,687] Trial 36 finished with value: 0.021797117755737557 and parameters: {'iterations': 1386, 'depth': 6, 'learning_rate': 0.23080857146285436, 'l2_leaf_reg': 7.308731505081221, 'border_count': 119}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:07,435] Trial 37 finished with value: 0.024505922678648102 and parameters: {'iterations': 1022, 'depth': 7, 'learning_rate': 0.10781085559950049, 'l2_leaf_reg': 6.849146117663029, 'border_count': 208}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:08,105] Trial 38 finished with value: 0.023971494458322917 and parameters: {'iterations': 1885, 'depth': 9, 'learning_rate': 0.17467554244130523, 'l2_leaf_reg': 7.591192609236811, 'border_count': 192}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:08,847] Trial 39 finished with value: 0.02275400423941782 and parameters: {'iterations': 1235, 'depth': 6, 'learning_rate': 0.144685826666152, 'l2_leaf_reg': 8.542357076837195, 'border_count': 42}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:09,199] Trial 40 finished with value: 0.02805890869649297 and parameters: {'iterations': 1648, 'depth': 8, 'learning_rate': 0.2016210911134204, 'l2_leaf_reg': 4.086412930713971, 'border_count': 242}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:09,734] Trial 41 finished with value: 0.021716523299640227 and parameters: {'iterations': 1719, 'depth': 4, 'learning_rate': 0.19657682640505517, 'l2_leaf_reg': 9.424737696665776, 'border_count': 106}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:10,143] Trial 42 finished with value: 0.024018396848294172 and parameters: {'iterations': 1928, 'depth': 5, 'learning_rate': 0.22343604364957015, 'l2_leaf_reg': 9.136990240700822, 'border_count': 76}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:10,528] Trial 43 finished with value: 0.023172067423598598 and parameters: {'iterations': 1787, 'depth': 4, 'learning_rate': 0.1840706081993376, 'l2_leaf_reg': 8.2506505569008, 'border_count': 113}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:11,103] Trial 44 finished with value: 0.022832923532608258 and parameters: {'iterations': 1605, 'depth': 5, 'learning_rate': 0.2523154171835562, 'l2_leaf_reg': 8.890353762171477, 'border_count': 142}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:11,518] Trial 45 finished with value: 0.02060775564422949 and parameters: {'iterations': 1865, 'depth': 4, 'learning_rate': 0.21297413780453672, 'l2_leaf_reg': 9.755637446248887, 'border_count': 130}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:12,822] Trial 46 finished with value: 0.023013470939492995 and parameters: {'iterations': 1399, 'depth': 7, 'learning_rate': 0.06013475586517744, 'l2_leaf_reg': 5.7236992293746365, 'border_count': 98}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:13,123] Trial 47 finished with value: 0.024140388885752827 and parameters: {'iterations': 1679, 'depth': 5, 'learning_rate': 0.26925801603527433, 'l2_leaf_reg': 3.4731941345296846, 'border_count': 154}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:14,044] Trial 48 finished with value: 0.022233594699233392 and parameters: {'iterations': 1562, 'depth': 7, 'learning_rate': 0.14576129225754225, 'l2_leaf_reg': 7.7648783538698485, 'border_count': 173}. Best is trial 24 with value: 0.018762710343842665.
# [I 2025-06-30 11:39:14,255] Trial 49 finished with value: 0.023337093025846103 and parameters: {'iterations': 1935, 'depth': 6, 'learning_rate': 0.28196582307655604, 'l2_leaf_reg': 0.7956663873289643, 'border_count': 114}. Best is trial 24 with value: 0.018762710343842665.
# Best Parameters: {'iterations': 1992, 'depth': 6, 'learning_rate': 0.188457495394322, 'l2_leaf_reg': 9.222947633613158, 'border_count': 107}
# Mean Absolute Error (Train): 0.03744254137303807
# Mean Squared Error (Train): 0.003584757764649239
# R2 Score (Train): 0.9964152422353507
# Adjusted R2 Score (Train): 0.9962274692095834
# Mean Absolute Error (Test): 0.10278582404389595
# Mean Squared Error (Test): 0.018762710343842665
# R2 Score (Test): 0.9849146469670973
# Adjusted R2 Score (Test): 0.9811433087088717
# 10-Fold Cross Validation Results:
# Avg RMSE: 0.2341549018417984
# Avg R2: 0.9331279366914893
# Avg MAE: 0.15594236007848916

# %%
# Save the trained CatBoost model to a file
final_model.save_model("model.cbm")
print("Model saved successfully as model.cbm")
# Out:
# Model saved successfully as model.cbm

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

y_test_orig = scaler_y.inverse_transform(y_test.reshape(-1, 1))  # Reshape to 2D array
pred_orig = scaler_y.inverse_transform(y_pred_val.reshape(-1, 1))  # Reshape to 2D array
# Fit linear regression through origin (y = mx)
reg = LinearRegression(fit_intercept=False)
reg.fit(y_test_orig, pred_orig)
m = reg.coef_[0][0]

# Prepare data for lines
line_x = np.linspace(0, max(y_test_orig.max(), pred_orig.max()), 100)
line_y = m * line_x
# Set font to Times New Roman
plt.rcParams["font.family"] = "Times New Roman"
# Plot
plt.figure(figsize=(12, 6))
plt.scatter(y_test_orig, pred_orig, color='blue',s=100)
plt.plot(line_x, line_y, 'r--', label=f'CB (y = {m:.4f}x)', linewidth=4)
plt.plot(line_x, line_x, 'k-',linewidth=3)
plt.xlabel('Experimental Pn',fontsize=28)
plt.ylabel('Predicted Pn',fontsize=28)
plt.legend(fontsize=28)
plt.grid(True)
plt.xlim(left=0)
plt.ylim(bottom=0)
# Change font size for axis ranges (tick labels)
plt.tick_params(axis='both', labelsize=22)  # Change font size of both x and y ticks
plt.tight_layout()
plt.savefig('CB', dpi=300)
plt.show()

# %%
import shap
import matplotlib.pyplot as plt
import seaborn as sns
# Set font to Times New Roman
plt.rcParams["font.family"] = "Times New Roman"
# SHAP Explainer
explainer = shap.Explainer(final_model)
shap_values = explainer(X)

# --- SHAP Summary Plot ---
shap.summary_plot(shap_values, X)

# --- Mean Absolute SHAP Value Plot ---
mean_abs_shap = pd.DataFrame({
    'Feature': X.columns,
    'Mean |SHAP|': np.abs(shap_values.values).mean(axis=0)
}).sort_values(by='Mean |SHAP|', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(data=mean_abs_shap, x='Mean |SHAP|', y='Feature', palette='viridis')
plt.title('Feature Importance (Mean |SHAP| Values)')
plt.tight_layout()
plt.show()

# --- Save SHAP Summary Plot ---
plt.figure()
shap.summary_plot(shap_values, X, show=False)
plt.tight_layout()
plt.savefig("shap_summary_plot.png", dpi=600, bbox_inches='tight')
plt.close()

# --- Save Mean |SHAP| Bar Plot ---
plt.figure(figsize=(10, 6))
sns.barplot(data=mean_abs_shap, x='Mean |SHAP|', y='Feature', palette='viridis')
plt.title('Feature Importance (Mean |SHAP| Values)')
plt.tight_layout()
plt.savefig("mean_abs_shap_importance.png", dpi=600, bbox_inches='tight')
plt.close()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6088\2366145643.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=mean_abs_shap, x='Mean |SHAP|', y='Feature', palette='viridis')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6088\2366145643.py:34: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=mean_abs_shap, x='Mean |SHAP|', y='Feature', palette='viridis')

# %%
output_file = "catboost_model.joblib"
joblib.dump((final_model, scaler_X, scaler_y), output_file)

print(f"Model and scalers saved to {output_file}")

# %%
import numpy as np

def calculate_taylor_stats(observed, predicted):
    """
    Calculate Taylor diagram statistics:
    correlation coefficient (R), centered RMS difference (RMSD), and predicted std deviation (sigma).
    """
    obs_mean = np.mean(observed)
    pred_mean = np.mean(predicted)
    
    obs_centered = observed - obs_mean
    pred_centered = predicted - pred_mean
    
    sigma_pred = np.std(pred_centered, ddof=1)
    R = np.corrcoef(observed, predicted)[0, 1]
    RMSD = np.sqrt(np.mean((pred_centered - obs_centered)**2))
    
    return R, RMSD, sigma_pred

# Inverse transform true and predicted test values to original scale
y_test_orig = scaler_y.inverse_transform(y_test.reshape(-1, 1)).ravel()
y_pred_orig = scaler_y.inverse_transform(y_pred_val.reshape(-1, 1)).ravel()

# Calculate Taylor diagram stats for the final model
R, RMSD, sigma_pred = calculate_taylor_stats(y_test_orig, y_pred_orig)

print("\nTaylor Diagram Statistics for Final Model on Test Data:")
print(f"Correlation coefficient (R): {R:.4f}")
print(f"Centered RMS difference (RMSD): {RMSD:.4f}")
print(f"Predicted standard deviation (σ): {sigma_pred:.4f}")
# Out:
# Taylor Diagram Statistics for Final Model on Test Data:
# Correlation coefficient (R): 0.9925
# Centered RMS difference (RMSD): 0.4824
# Predicted standard deviation (σ): 3.8821

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the existing image
image_path = shap_summary_plot.png"
img = mpimg.imread(image_path)

# Create a new figure and display the image
fig, ax = plt.subplots(figsize=(10, 6))
ax.imshow(img)
ax.axis('off')  # Turn off axes for cleaner look

# Add text with subscripts and superscripts
# Example: Adding a label at a specific position
ax.text(300, 100, r'$f_{u1}/f_{y1}$', fontsize=14, color='black')  # Example with subscript
ax.text(300, 200, r'$e^{2}/d$', fontsize=14, color='black')        # Example with superscript
ax.text(300, 300, r'$N_{b}$', fontsize=14, color='black')          # Subscript example

# Save the updated image
output_path = "shap_summary_plot_with_text.png"
plt.savefig(output_path, dpi=300, bbox_inches='tight')
plt.close()

output_path
# Out:
#   Cell In[6], line 5
#     image_path = shap_summary_plot.png"
#                                       ^
# SyntaxError: unterminated string literal (detected at line 5)
